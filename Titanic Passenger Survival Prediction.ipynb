# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.metrics import accuracy_score
from tensorflow import keras

# %%
df=pd.read_csv("Titanic-Dataset.csv")
print(df.head)
# Out:
# <bound method NDFrame.head of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]>

# %%
df.drop(["PassengerId","Name","Ticket","Cabin"],axis=1,inplace=True)

df["Age"]=df["Age"].fillna(df["Age"].mode()[0])

# %%
le=LabelEncoder()
df['Sex']=le.fit_transform(df['Sex'])
df['Embarked']=le.fit_transform(df['Embarked'])

# %%
X=df.drop("Survived",axis=1)
y=df["Survived"]

# %%
scaler=StandardScaler()
X=scaler.fit_transform(X)

X_train,X_test,y_train,y_test=train_test_split(X, y,test_size=0.2)

# %%
model=keras.Sequential([
    keras.Input(shape=(X_train.shape[1],)),
    
    keras.layers.Dense(256,activation="relu"),
    
    keras.layers.BatchNormalization(),
    
    keras.layers.Dropout(0.3),
    
    keras.layers.Dense(128,activation="relu"),
    
    keras.layers.BatchNormalization(),
    
    keras.layers.Dropout(0.3),

    
    keras.layers.Dense(64,activation="relu"),
    
    keras.layers.BatchNormalization(),
    
    keras.layers.Dropout(0.3),


    keras.layers.Dense(32,activation="relu"),
    
    keras.layers.BatchNormalization(),
    
    keras.layers.Dropout(0.3),

    
    keras.layers.Dense(16,activation="relu"),
    
    keras.layers.BatchNormalization(),
    
    keras.layers.Dropout(0.3),

    
    keras.layers.Dense(8,activation="relu"),
    
    keras.layers.BatchNormalization(),
    
    keras.layers.Dropout(0.3),
    
    keras.layers.Dense(4,activation="relu"),
    
    keras.layers.BatchNormalization(),
    
    keras.layers.Dropout(0.3),


    keras.layers.Dense(1,activation="sigmoid")
]);
print("Model Successfully Trained!!")
# Out:
# Model Successfully Trained!!

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
model.fit(X_train,y_train,epochs=50)
# Out:
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5421 - loss: 0.8508
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5548 - loss: 0.8309
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5955 - loss: 0.7353
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6713 - loss: 0.6646
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6292 - loss: 0.7118
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6685 - loss: 0.6301
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6980 - loss: 0.5982
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6615 - loss: 0.6297
# Epoch 9/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6699 - loss: 0.6132
# Epoch 10/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6573 - loss: 0.6210
# Epoch 11/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6994 - loss: 0.6024
# Epoch 12/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7008 - loss: 0.5815
# Epoch 13/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7247 - loss: 0.5636
# Epoch 14/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7191 - loss: 0.5681
# Epoch 15/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7107 - loss: 0.5737
# Epoch 16/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7402 - loss: 0.5813
# Epoch 17/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7458 - loss: 0.5311
# Epoch 18/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7626 - loss: 0.5360
# Epoch 19/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7430 - loss: 0.5541
# Epoch 20/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7654 - loss: 0.5375
# Epoch 21/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7416 - loss: 0.5311
# Epoch 22/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7584 - loss: 0.5406
# Epoch 23/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7556 - loss: 0.5377
# Epoch 24/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7584 - loss: 0.5173
# Epoch 25/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7781 - loss: 0.4971
# Epoch 26/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7879 - loss: 0.5108
# Epoch 27/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7978 - loss: 0.5051
# Epoch 28/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7654 - loss: 0.5292
# Epoch 29/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8006 - loss: 0.4813
# Epoch 30/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8020 - loss: 0.4759
# Epoch 31/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7767 - loss: 0.5210
# Epoch 32/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7823 - loss: 0.4962
# Epoch 33/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7739 - loss: 0.5217
# Epoch 34/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7739 - loss: 0.5174
# Epoch 35/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7851 - loss: 0.5020
# Epoch 36/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7879 - loss: 0.5017
# Epoch 37/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7978 - loss: 0.4897
# Epoch 38/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8118 - loss: 0.4976
# Epoch 39/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7935 - loss: 0.4945
# Epoch 40/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7978 - loss: 0.4794
# Epoch 41/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7978 - loss: 0.4760
# Epoch 42/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8020 - loss: 0.4804
# Epoch 43/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8034 - loss: 0.4741
# Epoch 44/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7921 - loss: 0.4749
# Epoch 45/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7992 - loss: 0.5046
# Epoch 46/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7865 - loss: 0.4659
# Epoch 47/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7907 - loss: 0.4751
# Epoch 48/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7978 - loss: 0.4738
# Epoch 49/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8062 - loss: 0.4799
# Epoch 50/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8132 - loss: 0.4727

# %%
y_pred=(model.predict(X_test)>0.5).astype(int)

print("Accuracy",accuracy_score(y_test,y_pred))
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Accuracy 0.7988826815642458

# %%
new_data=pd.DataFrame([[3,1,22,1,0,7.25,2]], columns=["Pclass","Sex","Age","SibSp","Parch","Fare","Embarked"])
new_data=scaler.transform(new_data)
predictions=model.predict(new_data)

print("Survived" if predictions[0][0] > 0.5 else "Not Survived")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Not Survived

# %%
import joblib


model.save("titanic_model.h5")  
from tensorflow import keras
model = keras.models.load_model("titanic_model.h5")

import joblib

joblib.dump(scaler, "scaler.pkl")
joblib.dump(le, "labelencoder.pkl")
scaler = joblib.load("scaler.pkl")
le = joblib.load("labelencoder.pkl")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
